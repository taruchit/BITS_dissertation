# %%
# %pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages (3.9.4)
# Requirement already satisfied: python-dateutil>=2.7 in /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages (from matplotlib) (2.9.0)
# Requirement already satisfied: fonttools>=4.22.0 in /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages (from matplotlib) (4.56.0)
# Requirement already satisfied: pillow>=8 in /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages (from matplotlib) (11.1.0)
# Requirement already satisfied: importlib-resources>=3.2.0 in /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages (from matplotlib) (6.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages (from matplotlib) (3.2.1)
# Requirement already satisfied: cycler>=0.10 in /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: packaging>=20.0 in /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages (from matplotlib) (24.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages (from matplotlib) (1.4.7)
# Requirement already satisfied: contourpy>=1.0.1 in /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages (from matplotlib) (1.3.0)
# Requirement already satisfied: numpy>=1.23 in /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages (from matplotlib) (2.0.2)
# Requirement already satisfied: zipp>=3.1.0 in /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages (from importlib-resources>=3.2.0->matplotlib) (3.17.0)
# Requirement already satisfied: six>=1.5 in /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.metrics import recall_score, accuracy_score, precision_score, f1_score, confusion_matrix, roc_curve, auc, roc_auc_score, balanced_accuracy_score, matthews_corrcoef, cohen_kappa_score, precision_recall_curve
from sklearn.neighbors import KNeighborsClassifier
from sklearn.preprocessing import StandardScaler

# %%
def model_evaluation(y_test, y_pred):
  print("model_evaluation method has started")
  cm=confusion_matrix(y_test, y_pred)
  accuracy=accuracy_score(y_test,y_pred)
  precision_value=precision_score(y_test, y_pred)
  recall_value=recall_score(y_test, y_pred, average='binary')
  f1_score_value=f1_score(y_test, y_pred, average='binary')
  fpr, tpr, thresholds = roc_curve(y_test, y_pred)
  roc_auc=auc(fpr, tpr)
  auc_score=roc_auc_score(y_test, y_pred)
  balanced_accuracy=balanced_accuracy_score(y_test, y_pred)
  mcc=matthews_corrcoef(y_test, y_pred)
  tn=cm[0, 0]
  fn=cm[1, 0]
  total_negative=tn+fn
  npv=tn/total_negative
  fp=cm[0, 1]
  tp=cm[1, 1]
  total_positive=tp+fp
  fdr=fp/total_positive
  cohen_kappa=cohen_kappa_score(y_test, y_pred)
  precision, recall, thresholds=precision_recall_curve(y_test, y_pred)
  pr_auc=auc(recall, precision)
  print("Confusion matrix = ",cm)
  print("Accuracy = ",round(accuracy,3))
  print("Precision = ",round(precision_value,3))
  print("Recall = ",round(recall_value,3))
  print("F1-Score = ",round(f1_score_value,3))
  plt.figure()
  plt.plot(fpr, tpr, color='darkorange', lw=2, label='ROC curve (area = %0.2f)' % roc_auc)
  plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
  plt.xlim([0.0, 1.0])
  plt.ylim([0.0, 1.05])
  plt.xlabel('False Positive Rate')
  plt.ylabel('True Positive Rate', rotation=0, labelpad=25)
  plt.title('Receiver Operating Characteristic (ROC) Curve')
  plt.legend(loc="lower right")
  plt.show()
  print("AUC score: ",round(auc_score,3))
  print("Balanced accuracy score: ",round(balanced_accuracy,3))
  print("Matthews Correlation Coefficient (MCC): ",round(mcc,3))
  print("Negative predictive value: ",round(npv,3))
  print("False discovery rate: ",round(fdr,3))
  print("Cohen kappa score: ",round(cohen_kappa,3))
  plt.figure()
  plt.plot(recall, precision, color='blue', lw=2, label='Precision-Recall curve (area = %0.2f)' % pr_auc)
  plt.xlabel('Recall')
  plt.ylabel('Precision', rotation=0, labelpad=10)
  plt.title('Precision-Recall Curve')
  plt.legend(loc="lower left")
  plt.show()
  print("model_evaluation method has ended")

# %%
def training_knn(X_scaled, y_train, selected_features):
  print("training_knn method has started")
  X_train_selected=X_scaled[:, selected_features]
  knn_model=KNeighborsClassifier()
  knn_model.fit(X_train_selected, y_train)
  print("training_knn method has ended")
  return knn_model

# %%
def testing_kNNClassifier(X_test, y_test, selected_features, knn_model):
  print("testing_kNNClassifier has started")
  X_test_selected=X_test[:, selected_features]
  y_pred=knn_model.predict(X_test_selected)
  model_evaluation(y_test, y_pred)
  print("testing_kNNClassifier has ended")

# %%
def evaluating_knn_model(knn_model, X_test, y_test, selected_features):
  print("evaluating_knn_model method has started")
  #Standardizing distribution of independent features in balanced test dataset using Standard Scaler
  scaler_test=StandardScaler()
  model_test=scaler_test.fit(X_test)
  X_test_scaled=model_test.transform(X_test)
  print("X_test_scaled: ",X_test_scaled)
  testing_kNNClassifier(X_test_scaled, y_test, selected_features, knn_model)
  print("evaluating_knn_model method has ended")

# %%
#Loading the training dataset
cic_df=pd.read_parquet("binary_training_data.parquet")

# %%
cic_df.head()
# Out:
#    Flow_Duration  Total_Fwd_Packets  Total_Backward_Packets  \
# 0      2999994.0                4.0                     0.0
# 1        11487.0                3.0                     4.0
# 2         9818.0                3.0                     4.0
# 3        10138.0                3.0                     4.0
# 4          109.0                3.0                     1.0
#
#    Fwd_Packets_Length_Total  Bwd_Packets_Length_Total  Fwd_Packet_Length_Max  \
# 0                    2064.0                       0.0                  516.0
# 1                     326.0                     129.0                  326.0
# 2                     326.0                     129.0                  326.0
# 3                     326.0                     129.0                  326.0
# 4                      53.0                       0.0                   53.0
#
#    Fwd_Packet_Length_Mean  Fwd_Packet_Length_Std  Bwd_Packet_Length_Max  \
# 0               44.000000               0.000000                    0.0
# 1              108.666664             188.216187                  112.0
# 2              108.666664             188.216187                  112.0
# 3              108.666664             188.216187                  112.0
# 4               17.666666              30.599564                    0.0
#
#    Bwd_Packet_Length_Mean  ...  Avg_Fwd_Segment_Size  Avg_Bwd_Segment_Size  \
# 0                    0.00  ...             44.000000                  0.00
# 1                   32.25  ...            108.666664                 32.25
# 2                   32.25  ...            108.666664                 32.25
# 3                   32.25  ...            108.666664                 32.25
# 4                    0.00  ...             17.666666                  0.00
#
#    Subflow_Fwd_Packets  Subflow_Fwd_Bytes  Subflow_Bwd_Packets  \
# 0                  4.0             2064.0                  0.0
# 1                  3.0              326.0                  4.0
# 2                  3.0              326.0                  4.0
# 3                  3.0              326.0                  4.0
# 4                  3.0               53.0                  1.0
#
#    Subflow_Bwd_Bytes  Init_Fwd_Win_Bytes  Fwd_Act_Data_Packets  \
# 0                0.0              8192.0                   3.0
# 1              129.0              8192.0                   1.0
# 2              129.0              8192.0                   1.0
# 3              129.0              8192.0                   1.0
# 4                0.0              1080.0                   1.0
#
#    Fwd_Seg_Size_Min  isMalicious
# 0              20.0            1
# 1              20.0            1
# 2              20.0            1
# 3              20.0            1
# 4              20.0            0
#
# [5 rows x 46 columns]

# %%
cic_df.tail()
# Out:
#        Flow_Duration  Total_Fwd_Packets  Total_Backward_Packets  \
# 82179         9749.0                3.0                     4.0
# 82180       343659.0                3.0                     2.0
# 82181         5401.0                2.0                     0.0
# 82182       412081.0                3.0                     2.0
# 82183       305105.0               12.0                     0.0
#
#        Fwd_Packets_Length_Total  Bwd_Packets_Length_Total  \
# 82179                     326.0                     129.0
# 82180                    1912.0                     232.0
# 82181                       0.0                       0.0
# 82182                    1912.0                     232.0
# 82183                      97.0                       0.0
#
#        Fwd_Packet_Length_Max  Fwd_Packet_Length_Mean  Fwd_Packet_Length_Std  \
# 82179                  326.0              108.666664             188.216187
# 82180                  640.0               86.909088             137.688019
# 82181                    0.0                0.000000               0.000000
# 82182                  640.0               83.130432             135.737488
# 82183                  440.0               44.000000               0.000000
#
#        Bwd_Packet_Length_Max  Bwd_Packet_Length_Mean  ...  \
# 82179                  112.0                32.25000  ...
# 82180                  976.0               121.13636  ...
# 82181                    0.0                 0.00000  ...
# 82182                  976.0               121.13636  ...
# 82183                    0.0                 0.00000  ...
#
#        Avg_Fwd_Segment_Size  Avg_Bwd_Segment_Size  Subflow_Fwd_Packets  \
# 82179            108.666664              32.25000                  3.0
# 82180             86.909088             121.13636                  3.0
# 82181              0.000000               0.00000                  2.0
# 82182             83.130432             121.13636                  3.0
# 82183             44.000000               0.00000                 12.0
#
#        Subflow_Fwd_Bytes  Subflow_Bwd_Packets  Subflow_Bwd_Bytes  \
# 82179              326.0                  4.0              129.0
# 82180             1912.0                  2.0              232.0
# 82181                0.0                  0.0                0.0
# 82182             1912.0                  2.0              232.0
# 82183               97.0                  0.0                0.0
#
#        Init_Fwd_Win_Bytes  Fwd_Act_Data_Packets  Fwd_Seg_Size_Min  isMalicious
# 82179              8192.0                   1.0              20.0            1
# 82180             26883.0                   1.0              32.0            1
# 82181             32738.0                   0.0              20.0            1
# 82182             26883.0                   1.0              32.0            1
# 82183              8192.0                   1.0              20.0            1
#
# [5 rows x 46 columns]

# %%
cic_df.shape
# Out:
# (82184, 46)

# %%
#Dividing the dataset into Independent and Dependent features
X=cic_df.iloc[:, 0:-1]
y=cic_df.iloc[:, -1]

# %%
X
# Out:
#        Flow_Duration  Total_Fwd_Packets  Total_Backward_Packets  \
# 0          2999994.0                4.0                     0.0
# 1            11487.0                3.0                     4.0
# 2             9818.0                3.0                     4.0
# 3            10138.0                3.0                     4.0
# 4              109.0                3.0                     1.0
# ...              ...                ...                     ...
# 82179         9749.0                3.0                     4.0
# 82180       343659.0                3.0                     2.0
# 82181         5401.0                2.0                     0.0
# 82182       412081.0                3.0                     2.0
# 82183       305105.0               12.0                     0.0
#
#        Fwd_Packets_Length_Total  Bwd_Packets_Length_Total  \
# 0                        2064.0                       0.0
# 1                         326.0                     129.0
# 2                         326.0                     129.0
# 3                         326.0                     129.0
# 4                          53.0                       0.0
# ...                         ...                       ...
# 82179                     326.0                     129.0
# 82180                    1912.0                     232.0
# 82181                       0.0                       0.0
# 82182                    1912.0                     232.0
# 82183                      97.0                       0.0
#
#        Fwd_Packet_Length_Max  Fwd_Packet_Length_Mean  Fwd_Packet_Length_Std  \
# 0                      516.0               44.000000               0.000000
# 1                      326.0              108.666664             188.216187
# 2                      326.0              108.666664             188.216187
# 3                      326.0              108.666664             188.216187
# 4                       53.0               17.666666              30.599564
# ...                      ...                     ...                    ...
# 82179                  326.0              108.666664             188.216187
# 82180                  640.0               86.909088             137.688019
# 82181                    0.0                0.000000               0.000000
# 82182                  640.0               83.130432             135.737488
# 82183                  440.0               44.000000               0.000000
#
#        Bwd_Packet_Length_Max  Bwd_Packet_Length_Mean  ...  Avg_Packet_Size  \
# 0                        0.0                 0.00000  ...        99.500000
# 1                      112.0                32.25000  ...        65.000000
# 2                      112.0                32.25000  ...        65.000000
# 3                      112.0                32.25000  ...        65.000000
# 4                        0.0                 0.00000  ...        13.250000
# ...                      ...                     ...  ...              ...
# 82179                  112.0                32.25000  ...        65.000000
# 82180                  976.0               121.13636  ...       104.022728
# 82181                    0.0                 0.00000  ...         0.000000
# 82182                  976.0               121.13636  ...       101.711113
# 82183                    0.0                 0.00000  ...        99.500000
#
#        Avg_Fwd_Segment_Size  Avg_Bwd_Segment_Size  Subflow_Fwd_Packets  \
# 0                 44.000000               0.00000                  4.0
# 1                108.666664              32.25000                  3.0
# 2                108.666664              32.25000                  3.0
# 3                108.666664              32.25000                  3.0
# 4                 17.666666               0.00000                  3.0
# ...                     ...                   ...                  ...
# 82179            108.666664              32.25000                  3.0
# 82180             86.909088             121.13636                  3.0
# 82181              0.000000               0.00000                  2.0
# 82182             83.130432             121.13636                  3.0
# 82183             44.000000               0.00000                 12.0
#
#        Subflow_Fwd_Bytes  Subflow_Bwd_Packets  Subflow_Bwd_Bytes  \
# 0                 2064.0                  0.0                0.0
# 1                  326.0                  4.0              129.0
# 2                  326.0                  4.0              129.0
# 3                  326.0                  4.0              129.0
# 4                   53.0                  1.0                0.0
# ...                  ...                  ...                ...
# 82179              326.0                  4.0              129.0
# 82180             1912.0                  2.0              232.0
# 82181                0.0                  0.0                0.0
# 82182             1912.0                  2.0              232.0
# 82183               97.0                  0.0                0.0
#
#        Init_Fwd_Win_Bytes  Fwd_Act_Data_Packets  Fwd_Seg_Size_Min
# 0                  8192.0                   3.0              20.0
# 1                  8192.0                   1.0              20.0
# 2                  8192.0                   1.0              20.0
# 3                  8192.0                   1.0              20.0
# 4                  1080.0                   1.0              20.0
# ...                   ...                   ...               ...
# 82179              8192.0                   1.0              20.0
# 82180             26883.0                   1.0              32.0
# 82181             32738.0                   0.0              20.0
# 82182             26883.0                   1.0              32.0
# 82183              8192.0                   1.0              20.0
#
# [82184 rows x 45 columns]

# %%
y
# Out:
# 0        1
# 1        1
# 2        1
# 3        1
# 4        0
#         ..
# 82179    1
# 82180    1
# 82181    1
# 82182    1
# 82183    1
# Name: isMalicious, Length: 82184, dtype: int32

# %%
#Standardizing distribution of independent features using Standard Scaler
scaler=StandardScaler()
model=scaler.fit(X)
X_scaled=model.transform(X)
print(X_scaled)
# Out:
# [[ 0.97032358  0.28641171 -1.41438795 ... -0.47471168  1.04736257
#   -0.40746592]
#  [-0.43014952 -0.20728475  0.72432392 ... -0.47471168 -0.23363223
#   -0.40746592]
#  [-0.43093165 -0.20728475  0.72432392 ... -0.47471168 -0.23363223
#   -0.40746592]
#  ...
#  [-0.43300154 -0.70098122 -1.41438795 ...  1.1193544  -0.87412963
#   -0.40746592]
#  [-0.2424233  -0.20728475 -0.34503202 ...  0.73911905 -0.23363223
#    1.36375676]
#  [-0.29255435  4.23598345 -1.41438795 ... -0.47471168 -0.23363223
#   -0.40746592]]

# %%
selected_features=[0, 1, 4, 5, 6, 10, 13, 15, 17, 19, 22, 23, 24, 27, 28, 30, 31, 34, 39, 40, 41, 42]

# %%
print("List of selected features: ",selected_features)
print("Number of features selected: ",len(selected_features))
# Out:
# List of selected features:  [0, 1, 4, 5, 6, 10, 13, 15, 17, 19, 22, 23, 24, 27, 28, 30, 31, 34, 39, 40, 41, 42]
# Number of features selected:  22

# %% [markdown]
# # Training the Binary classifier using KNN algorithm

# %%
knn_model=training_knn(X_scaled, y, selected_features)
# Out:
# training_knn method has started
# training_knn method has ended

# %% [markdown]
# We have performed training of binary classifier using KNN algorithm.
#
# Now we will perform evaluation the model using test datasets.
#
# 1. For balanced test dataset, we will use binary_balanced_test_data.parquet
# 2. For imbalanced test dataset, we will use binary_imbalanced_test_data.parquet

# %% [markdown]
# # Evaluation of Balanced test dataset.

# %%
#Loading the balanced test dataset
balanced_test_cic_df=pd.read_parquet("binary_balanced_test_data.parquet")

# %%
balanced_test_cic_df.head()
# Out:
#    Flow_Duration  Total_Fwd_Packets  Total_Backward_Packets  \
# 0      1921793.0                3.0                     4.0
# 1       396502.0                3.0                     2.0
# 2       380665.0                3.0                     2.0
# 3       155005.0                1.0                     1.0
# 4        11496.0                3.0                     4.0
#
#    Fwd_Packets_Length_Total  Bwd_Packets_Length_Total  Fwd_Packet_Length_Max  \
# 0                      20.0                     964.0                   20.0
# 1                     855.0                     232.0                  210.0
# 2                    1992.0                     232.0                  640.0
# 3                      44.0                     111.0                   44.0
# 4                     326.0                     129.0                  326.0
#
#    Fwd_Packet_Length_Mean  Fwd_Packet_Length_Std  Bwd_Packet_Length_Max  \
# 0                6.666667              11.547006                  964.0
# 1               53.437500              75.622719                 1430.0
# 2               90.545456             138.109940                  976.0
# 3               44.000000               0.000000                  111.0
# 4              108.666664             188.216187                  112.0
#
#    Bwd_Packet_Length_Mean  ...  Avg_Fwd_Segment_Size  Avg_Bwd_Segment_Size  \
# 0              241.000000  ...              6.666667            241.000000
# 1              365.000000  ...             53.437500            365.000000
# 2              126.904762  ...             90.545456            126.904762
# 3              111.000000  ...             44.000000            111.000000
# 4               32.250000  ...            108.666664             32.250000
#
#    Subflow_Fwd_Packets  Subflow_Fwd_Bytes  Subflow_Bwd_Packets  \
# 0                  3.0               20.0                  4.0
# 1                  3.0              855.0                  2.0
# 2                  3.0             1992.0                  2.0
# 3                  1.0               44.0                  1.0
# 4                  3.0              326.0                  4.0
#
#    Subflow_Bwd_Bytes  Init_Fwd_Win_Bytes  Fwd_Act_Data_Packets  \
# 0              964.0              8192.0                   1.0
# 1              232.0              8192.0                   8.0
# 2              232.0             26883.0                   1.0
# 3              111.0              8192.0                   0.0
# 4              129.0              8192.0                   1.0
#
#    Fwd_Seg_Size_Min  isMalicious
# 0              20.0            1
# 1              20.0            0
# 2              32.0            1
# 3              32.0            0
# 4              20.0            1
#
# [5 rows x 46 columns]

# %%
balanced_test_cic_df.tail()
# Out:
#        Flow_Duration  Total_Fwd_Packets  Total_Backward_Packets  \
# 82763       396502.0                3.0                     2.0
# 82764      8018992.0                9.0                     2.0
# 82765       309531.0                3.0                     2.0
# 82766       375502.0                3.0                     2.0
# 82767       347252.0                3.0                     2.0
#
#        Fwd_Packets_Length_Total  Bwd_Packets_Length_Total  \
# 82763                      97.0                     232.0
# 82764                     116.0                     188.0
# 82765                    1928.0                     232.0
# 82766                    1912.0                     232.0
# 82767                    1928.0                     232.0
#
#        Fwd_Packet_Length_Max  Fwd_Packet_Length_Mean  Fwd_Packet_Length_Std  \
# 82763                  405.0               29.321428              86.874672
# 82764                   35.0               12.888889              11.741427
# 82765                  640.0               87.636360             137.780548
# 82766                  640.0               83.130432             135.737488
# 82767                  640.0               87.636360             137.780548
#
#        Bwd_Packet_Length_Max  Bwd_Packet_Length_Mean  ...  \
# 82763                  152.0              108.000000  ...
# 82764                   34.0               12.533334  ...
# 82765                  976.0              121.136360  ...
# 82766                  976.0              133.250000  ...
# 82767                  976.0              121.136360  ...
#
#        Avg_Fwd_Segment_Size  Avg_Bwd_Segment_Size  Subflow_Fwd_Packets  \
# 82763             29.321428            108.000000                  3.0
# 82764             12.888889             12.533334                  9.0
# 82765             87.636360            121.136360                  3.0
# 82766             83.130432            133.250000                  3.0
# 82767             87.636360            121.136360                  3.0
#
#        Subflow_Fwd_Bytes  Subflow_Bwd_Packets  Subflow_Bwd_Bytes  \
# 82763               97.0                  2.0              232.0
# 82764              116.0                  2.0              188.0
# 82765             1928.0                  2.0              232.0
# 82766             1912.0                  2.0              232.0
# 82767             1928.0                  2.0              232.0
#
#        Init_Fwd_Win_Bytes  Fwd_Act_Data_Packets  Fwd_Seg_Size_Min  isMalicious
# 82763              8192.0                   1.0              20.0            0
# 82764             29200.0                   6.0              32.0            1
# 82765             26883.0                   1.0              32.0            1
# 82766             26883.0                   1.0              32.0            1
# 82767             26883.0                   1.0              32.0            1
#
# [5 rows x 46 columns]

# %%
balanced_test_cic_df.shape
# Out:
# (82768, 46)

# %%
#Dividing the balanced test dataset into Independent and Dependent features
X_balanced_test=balanced_test_cic_df.iloc[:, 0:-1]
y_balanced_test=balanced_test_cic_df.iloc[:, -1]

# %%
X_balanced_test
# Out:
#        Flow_Duration  Total_Fwd_Packets  Total_Backward_Packets  \
# 0          1921793.0                3.0                     4.0
# 1           396502.0                3.0                     2.0
# 2           380665.0                3.0                     2.0
# 3           155005.0                1.0                     1.0
# 4            11496.0                3.0                     4.0
# ...              ...                ...                     ...
# 82763       396502.0                3.0                     2.0
# 82764      8018992.0                9.0                     2.0
# 82765       309531.0                3.0                     2.0
# 82766       375502.0                3.0                     2.0
# 82767       347252.0                3.0                     2.0
#
#        Fwd_Packets_Length_Total  Bwd_Packets_Length_Total  \
# 0                          20.0                     964.0
# 1                         855.0                     232.0
# 2                        1992.0                     232.0
# 3                          44.0                     111.0
# 4                         326.0                     129.0
# ...                         ...                       ...
# 82763                      97.0                     232.0
# 82764                     116.0                     188.0
# 82765                    1928.0                     232.0
# 82766                    1912.0                     232.0
# 82767                    1928.0                     232.0
#
#        Fwd_Packet_Length_Max  Fwd_Packet_Length_Mean  Fwd_Packet_Length_Std  \
# 0                       20.0                6.666667              11.547006
# 1                      210.0               53.437500              75.622719
# 2                      640.0               90.545456             138.109940
# 3                       44.0               44.000000               0.000000
# 4                      326.0              108.666664             188.216187
# ...                      ...                     ...                    ...
# 82763                  405.0               29.321428              86.874672
# 82764                   35.0               12.888889              11.741427
# 82765                  640.0               87.636360             137.780548
# 82766                  640.0               83.130432             135.737488
# 82767                  640.0               87.636360             137.780548
#
#        Bwd_Packet_Length_Max  Bwd_Packet_Length_Mean  ...  Avg_Packet_Size  \
# 0                      964.0              241.000000  ...       140.571426
# 1                     1430.0              365.000000  ...       213.939392
# 2                      976.0              126.904762  ...       108.302322
# 3                      111.0              111.000000  ...        99.500000
# 4                      112.0               32.250000  ...        65.000000
# ...                      ...                     ...  ...              ...
# 82763                  152.0              108.000000  ...        99.500000
# 82764                   34.0               12.533334  ...        12.666667
# 82765                  976.0              121.136360  ...       104.386360
# 82766                  976.0              133.250000  ...       106.441864
# 82767                  976.0              121.136360  ...       104.386360
#
#        Avg_Fwd_Segment_Size  Avg_Bwd_Segment_Size  Subflow_Fwd_Packets  \
# 0                  6.666667            241.000000                  3.0
# 1                 53.437500            365.000000                  3.0
# 2                 90.545456            126.904762                  3.0
# 3                 44.000000            111.000000                  1.0
# 4                108.666664             32.250000                  3.0
# ...                     ...                   ...                  ...
# 82763             29.321428            108.000000                  3.0
# 82764             12.888889             12.533334                  9.0
# 82765             87.636360            121.136360                  3.0
# 82766             83.130432            133.250000                  3.0
# 82767             87.636360            121.136360                  3.0
#
#        Subflow_Fwd_Bytes  Subflow_Bwd_Packets  Subflow_Bwd_Bytes  \
# 0                   20.0                  4.0              964.0
# 1                  855.0                  2.0              232.0
# 2                 1992.0                  2.0              232.0
# 3                   44.0                  1.0              111.0
# 4                  326.0                  4.0              129.0
# ...                  ...                  ...                ...
# 82763               97.0                  2.0              232.0
# 82764              116.0                  2.0              188.0
# 82765             1928.0                  2.0              232.0
# 82766             1912.0                  2.0              232.0
# 82767             1928.0                  2.0              232.0
#
#        Init_Fwd_Win_Bytes  Fwd_Act_Data_Packets  Fwd_Seg_Size_Min
# 0                  8192.0                   1.0              20.0
# 1                  8192.0                   8.0              20.0
# 2                 26883.0                   1.0              32.0
# 3                  8192.0                   0.0              32.0
# 4                  8192.0                   1.0              20.0
# ...                   ...                   ...               ...
# 82763              8192.0                   1.0              20.0
# 82764             29200.0                   6.0              32.0
# 82765             26883.0                   1.0              32.0
# 82766             26883.0                   1.0              32.0
# 82767             26883.0                   1.0              32.0
#
# [82768 rows x 45 columns]

# %%
y_balanced_test
# Out:
# 0        1
# 1        0
# 2        1
# 3        0
# 4        1
#         ..
# 82763    0
# 82764    1
# 82765    1
# 82766    1
# 82767    1
# Name: isMalicious, Length: 82768, dtype: int32

# %%
print("Evaluating binary KNN classifier on Balanced dataset.")
evaluating_knn_model(knn_model, X_balanced_test, y_balanced_test, selected_features)
# Out:
# Evaluating binary KNN classifier on Balanced dataset.
# evaluating_knn_model method has started
# X_test_scaled:  [[ 0.46171602 -0.20831857  0.71420086 ... -0.47597631 -0.23266686
#   -0.41355401]
#  [-0.25089289 -0.20831857 -0.35031282 ... -0.47597631  4.25354162
#   -0.41355401]
#  [-0.25829187 -0.20831857 -0.35031282 ...  0.73879583 -0.23266686
#    1.36423152]
#  ...
#  [-0.29152534 -0.20831857 -0.35031282 ...  0.73879583 -0.23266686
#    1.36423152]
#  [-0.260704   -0.20831857 -0.35031282 ...  0.73879583 -0.23266686
#    1.36423152]
#  [-0.27390227 -0.20831857 -0.35031282 ...  0.73879583 -0.23266686
#    1.36423152]]
# testing_kNNClassifier has started
# model_evaluation method has started
# Confusion matrix =  [[20039   653]
#  [  304 61772]]
# Accuracy =  0.988
# Precision =  0.99
# Recall =  0.995
# F1-Score =  0.992
# AUC score:  0.982
# Balanced accuracy score:  0.982
# Matthews Correlation Coefficient (MCC):  0.969
# Negative predictive value:  0.985
# False discovery rate:  0.01
# Cohen kappa score:  0.969
# model_evaluation method has ended
# testing_kNNClassifier has ended
# evaluating_knn_model method has ended

# %% [markdown]
# # Evaluation of Imbalanced test dataset.

# %%
#Loading the imbalanced test dataset
imbalanced_test_cic_df=pd.read_parquet("binary_imbalanced_test_data.parquet")

# %%
imbalanced_test_cic_df.head()
# Out:
#          Flow_Duration  Total_Fwd_Packets  Total_Backward_Packets  \
# 7131407          400.0                3.0                     0.0
# 5064597       396502.0                3.0                     2.0
# 5116882      5750464.0                4.0                     4.0
# 201601         61133.0                1.0                     1.0
# 2619988         1113.0                1.0                     4.0
#
#          Fwd_Packets_Length_Total  Bwd_Packets_Length_Total  \
# 7131407                      97.0                       0.0
# 5064597                      97.0                     232.0
# 5116882                      97.0                     232.0
# 201601                       48.0                     110.0
# 2619988                       0.0                       0.0
#
#          Fwd_Packet_Length_Max  Fwd_Packet_Length_Mean  Fwd_Packet_Length_Std  \
# 7131407                  440.0               44.000000              66.483398
# 5064597                  584.0              119.550003             186.248688
# 5116882                   97.0               24.250000              48.500000
# 201601                    48.0               48.000000               0.000000
# 2619988                    0.0                0.000000               0.000000
#
#          Bwd_Packet_Length_Max  Bwd_Packet_Length_Mean  ...  \
# 7131407                    0.0                0.000000  ...
# 5064597                 1460.0              486.789459  ...
# 5116882                  232.0               58.000000  ...
# 201601                   110.0              110.000000  ...
# 2619988                    0.0                0.000000  ...
#
#          Avg_Fwd_Segment_Size  Avg_Bwd_Segment_Size  Subflow_Fwd_Packets  \
# 7131407             44.000000              0.000000                  3.0
# 5064597            119.550003            486.789459                  3.0
# 5116882             24.250000             58.000000                  4.0
# 201601              48.000000            110.000000                  1.0
# 2619988              0.000000              0.000000                  1.0
#
#          Subflow_Fwd_Bytes  Subflow_Bwd_Packets  Subflow_Bwd_Bytes  \
# 7131407               97.0                  0.0                0.0
# 5064597               97.0                  2.0              232.0
# 5116882               97.0                  4.0              232.0
# 201601                48.0                  1.0              110.0
# 2619988                0.0                  4.0                0.0
#
#          Init_Fwd_Win_Bytes  Fwd_Act_Data_Packets  Fwd_Seg_Size_Min  \
# 7131407              8192.0                   1.0               8.0
# 5064597              8192.0                   1.0              20.0
# 5116882              8192.0                   1.0              20.0
# 201601               8192.0                   0.0              32.0
# 2619988              8192.0                   0.0               8.0
#
#          isMalicious
# 7131407            1
# 5064597            0
# 5116882            0
# 201601             0
# 2619988            0
#
# [5 rows x 46 columns]

# %%
imbalanced_test_cic_df.tail()
# Out:
#          Flow_Duration  Total_Fwd_Packets  Total_Backward_Packets  \
# 3078048      1348605.0                3.0                     4.0
# 2853571       839685.0                3.0                     4.0
# 2638009      5604348.0                8.0                     4.0
# 2808894        44197.0                3.0                     4.0
# 1321597          259.0                2.0                     2.0
#
#          Fwd_Packets_Length_Total  Bwd_Packets_Length_Total  \
# 3078048                      20.0                     964.0
# 2853571                      20.0                     964.0
# 2638009                     612.0                     232.0
# 2808894                      26.0                     232.0
# 1321597                      72.0                     322.0
#
#          Fwd_Packet_Length_Max  Fwd_Packet_Length_Mean  Fwd_Packet_Length_Std  \
# 3078048                   20.0                6.666667              11.547006
# 2853571                   20.0                6.666667              11.547006
# 2638009                  342.0               76.500000             125.554771
# 2808894                   20.0                8.666667              10.263203
# 1321597                   36.0               36.000000               0.000000
#
#          Bwd_Packet_Length_Max  Bwd_Packet_Length_Mean  ...  \
# 3078048                  964.0                   241.0  ...
# 2853571                  964.0                   241.0  ...
# 2638009                 1460.0                   108.0  ...
# 2808894                  152.0                   108.0  ...
# 1321597                  161.0                   161.0  ...
#
#          Avg_Fwd_Segment_Size  Avg_Bwd_Segment_Size  Subflow_Fwd_Packets  \
# 3078048              6.666667                 241.0                  3.0
# 2853571              6.666667                 241.0                  3.0
# 2638009             76.500000                 108.0                  8.0
# 2808894              8.666667                 108.0                  3.0
# 1321597             36.000000                 161.0                  2.0
#
#          Subflow_Fwd_Bytes  Subflow_Bwd_Packets  Subflow_Bwd_Bytes  \
# 3078048               20.0                  4.0              964.0
# 2853571               20.0                  4.0              964.0
# 2638009              612.0                  4.0              232.0
# 2808894               26.0                  4.0              232.0
# 1321597               72.0                  2.0              322.0
#
#          Init_Fwd_Win_Bytes  Fwd_Act_Data_Packets  Fwd_Seg_Size_Min  \
# 3078048              8192.0                   1.0              20.0
# 2853571              8192.0                   1.0              20.0
# 2638009              8192.0                   7.0              20.0
# 2808894              8192.0                   2.0              20.0
# 1321597              8192.0                   1.0              32.0
#
#          isMalicious
# 3078048            1
# 2853571            1
# 2638009            0
# 2808894            1
# 1321597            0
#
# [5 rows x 46 columns]

# %%
imbalanced_test_cic_df.shape
# Out:
# (1734101, 46)

# %%
#Dividing the imbalanced test dataset into Independent and Dependent features
X_imbalanced_test=imbalanced_test_cic_df.iloc[:, 0:-1]
y_imbalanced_test=imbalanced_test_cic_df.iloc[:, -1]

# %%
X_imbalanced_test
# Out:
#          Flow_Duration  Total_Fwd_Packets  Total_Backward_Packets  \
# 7131407          400.0                3.0                     0.0
# 5064597       396502.0                3.0                     2.0
# 5116882      5750464.0                4.0                     4.0
# 201601         61133.0                1.0                     1.0
# 2619988         1113.0                1.0                     4.0
# ...                ...                ...                     ...
# 3078048      1348605.0                3.0                     4.0
# 2853571       839685.0                3.0                     4.0
# 2638009      5604348.0                8.0                     4.0
# 2808894        44197.0                3.0                     4.0
# 1321597          259.0                2.0                     2.0
#
#          Fwd_Packets_Length_Total  Bwd_Packets_Length_Total  \
# 7131407                      97.0                       0.0
# 5064597                      97.0                     232.0
# 5116882                      97.0                     232.0
# 201601                       48.0                     110.0
# 2619988                       0.0                       0.0
# ...                           ...                       ...
# 3078048                      20.0                     964.0
# 2853571                      20.0                     964.0
# 2638009                     612.0                     232.0
# 2808894                      26.0                     232.0
# 1321597                      72.0                     322.0
#
#          Fwd_Packet_Length_Max  Fwd_Packet_Length_Mean  Fwd_Packet_Length_Std  \
# 7131407                  440.0               44.000000              66.483398
# 5064597                  584.0              119.550003             186.248688
# 5116882                   97.0               24.250000              48.500000
# 201601                    48.0               48.000000               0.000000
# 2619988                    0.0                0.000000               0.000000
# ...                        ...                     ...                    ...
# 3078048                   20.0                6.666667              11.547006
# 2853571                   20.0                6.666667              11.547006
# 2638009                  342.0               76.500000             125.554771
# 2808894                   20.0                8.666667              10.263203
# 1321597                   36.0               36.000000               0.000000
#
#          Bwd_Packet_Length_Max  Bwd_Packet_Length_Mean  ...  Avg_Packet_Size  \
# 7131407                    0.0                0.000000  ...        99.500000
# 5064597                 1460.0              486.789459  ...       298.461548
# 5116882                  232.0               58.000000  ...        41.125000
# 201601                   110.0              110.000000  ...       103.000000
# 2619988                    0.0                0.000000  ...         0.000000
# ...                        ...                     ...  ...              ...
# 3078048                  964.0              241.000000  ...       140.571426
# 2853571                  964.0              241.000000  ...       140.571426
# 2638009                 1460.0              108.000000  ...       310.500000
# 2808894                  152.0              108.000000  ...        99.500000
# 1321597                  161.0              161.000000  ...       107.500000
#
#          Avg_Fwd_Segment_Size  Avg_Bwd_Segment_Size  Subflow_Fwd_Packets  \
# 7131407             44.000000              0.000000                  3.0
# 5064597            119.550003            486.789459                  3.0
# 5116882             24.250000             58.000000                  4.0
# 201601              48.000000            110.000000                  1.0
# 2619988              0.000000              0.000000                  1.0
# ...                       ...                   ...                  ...
# 3078048              6.666667            241.000000                  3.0
# 2853571              6.666667            241.000000                  3.0
# 2638009             76.500000            108.000000                  8.0
# 2808894              8.666667            108.000000                  3.0
# 1321597             36.000000            161.000000                  2.0
#
#          Subflow_Fwd_Bytes  Subflow_Bwd_Packets  Subflow_Bwd_Bytes  \
# 7131407               97.0                  0.0                0.0
# 5064597               97.0                  2.0              232.0
# 5116882               97.0                  4.0              232.0
# 201601                48.0                  1.0              110.0
# 2619988                0.0                  4.0                0.0
# ...                    ...                  ...                ...
# 3078048               20.0                  4.0              964.0
# 2853571               20.0                  4.0              964.0
# 2638009              612.0                  4.0              232.0
# 2808894               26.0                  4.0              232.0
# 1321597               72.0                  2.0              322.0
#
#          Init_Fwd_Win_Bytes  Fwd_Act_Data_Packets  Fwd_Seg_Size_Min
# 7131407              8192.0                   1.0               8.0
# 5064597              8192.0                   1.0              20.0
# 5116882              8192.0                   1.0              20.0
# 201601               8192.0                   0.0              32.0
# 2619988              8192.0                   0.0               8.0
# ...                     ...                   ...               ...
# 3078048              8192.0                   1.0              20.0
# 2853571              8192.0                   1.0              20.0
# 2638009              8192.0                   7.0              20.0
# 2808894              8192.0                   2.0              20.0
# 1321597              8192.0                   1.0              32.0
#
# [1734101 rows x 45 columns]

# %%
y_imbalanced_test
# Out:
# 7131407    1
# 5064597    0
# 5116882    0
# 201601     0
# 2619988    0
#           ..
# 3078048    1
# 2853571    1
# 2638009    0
# 2808894    1
# 1321597    0
# Name: isMalicious, Length: 1734101, dtype: int32

# %%
print("Evaluating binary KNN classifier on Imbalanced dataset.")
evaluating_knn_model(knn_model, X_imbalanced_test, y_imbalanced_test, selected_features)
# Out:
# Evaluating binary KNN classifier on Imbalanced dataset.
# evaluating_knn_model method has started
# X_test_scaled:  [[-0.56854838 -0.30500688 -1.07963986 ... -0.28203268 -0.34004088
#   -1.6987043 ]
#  [-0.3841412  -0.30500688 -0.27528921 ... -0.28203268 -0.34004088
#   -0.00274217]
#  [ 2.10842133  0.02058327  0.52906144 ... -0.28203268 -0.34004088
#   -0.00274217]
#  ...
#  [ 2.04039633  1.32294388  0.52906144 ... -0.28203268  2.39336023
#   -0.00274217]
#  [-0.54815848 -0.30500688  0.52906144 ... -0.28203268  0.11552597
#   -0.00274217]
#  [-0.56861402 -0.63059703 -0.27528921 ... -0.28203268 -0.34004088
#    1.69321996]]
# testing_kNNClassifier has started
# model_evaluation method has started
# Confusion matrix =  [[1407695   29469]
#  [  63295  233642]]
# Accuracy =  0.947
# Precision =  0.888
# Recall =  0.787
# F1-Score =  0.834
# AUC score:  0.883
# Balanced accuracy score:  0.883
# Matthews Correlation Coefficient (MCC):  0.805
# Negative predictive value:  0.957
# False discovery rate:  0.112
# Cohen kappa score:  0.803
# model_evaluation method has ended
# testing_kNNClassifier has ended
# evaluating_knn_model method has ended
