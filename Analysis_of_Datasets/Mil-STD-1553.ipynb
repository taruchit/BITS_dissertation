# %%
import pandas as pd

# %%
normal_df=pd.read_csv("..//Mil-STD-1553/Normal (Benign) Data/1553_Benign.csv")

# %%
normal_df.head()
# Out:
#    msgId   timestamp  error  modeCode channel connType  sa  ssa   da   dsa  \
# 0      1  254.842659  False      True       A   BC->RT NaN  NaN  1.0   0.0
# 1      2  254.842738  False      True       A   BC->RT NaN  NaN  2.0   0.0
# 2      3  254.842817  False      True       A   BC->RT NaN  NaN  3.0   0.0
# 3      4  254.842896  False      True       A   BC->RT NaN  NaN  4.0   0.0
# 4      5  254.843060  False     False       A   BC->RT NaN  NaN  1.0  20.0
#
#    ...  dw26  dw27  dw28 dw29  dw30 dw31 malicious injected   gap msgTime
# 0  ...   NaN   NaN   NaN  NaN   NaN  NaN     False    False   NaN    65.0
# 1  ...   NaN   NaN   NaN  NaN   NaN  NaN     False    False  14.0    65.0
# 2  ...   NaN   NaN   NaN  NaN   NaN  NaN     False    False  14.0    65.0
# 3  ...   NaN   NaN   NaN  NaN   NaN  NaN     False    False  14.0    65.0
# 4  ...   NaN   NaN   NaN  NaN   NaN  NaN     False    False  99.0    65.0
#
# [5 rows x 52 columns]

# %%
normal_df.tail()
# Out:
#        msgId   timestamp  error  modeCode channel connType   sa   ssa   da  \
# 22995  22996  806.593218  False     False       A   RT->BC  4.0   5.0  NaN
# 22996  22997  806.593297  False     False       A   RT->BC  4.0  30.0  NaN
# 22997  22998  806.593996  False     False       A   RT->BC  4.0   6.0  NaN
# 22998  22999  806.594095  False     False       A   RT->RT  1.0   1.0  3.0
# 22999  23000  806.594381  False     False       A   RT->RT  1.0   1.0  2.0
#
#        dsa  ...    dw26    dw27    dw28    dw29    dw30    dw31 malicious  \
# 22995  NaN  ...     NaN     NaN     NaN     NaN     NaN     NaN     False
# 22996  NaN  ...  0x0000  0x0000  0x0000  0x0000  0x0000  0x0000     False
# 22997  NaN  ...     NaN     NaN     NaN     NaN     NaN     NaN     False
# 22998  1.0  ...     NaN     NaN     NaN     NaN     NaN     NaN     False
# 22999  2.0  ...     NaN     NaN     NaN     NaN     NaN     NaN     False
#
#       injected   gap msgTime
# 22995    False  14.0    65.0
# ...

# %%
normal_df.shape
# Out:
# (23000, 52)

# %%
normal_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23000 entries, 0 to 22999
# Data columns (total 52 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   msgId        23000 non-null  int64
#  1   timestamp    23000 non-null  float64
#  2   error        23000 non-null  bool
#  3   modeCode     23000 non-null  bool
#  4   channel      23000 non-null  object
#  5   connType     23000 non-null  object
#  6   sa           11408 non-null  float64
#  7   ssa          11408 non-null  float64
#  8   da           16008 non-null  float64
#  9   dsa          16008 non-null  float64
#  10  wc           14168 non-null  float64
#  11  modeCodeVal  8832 non-null   float64
#  12  txRsp        11408 non-null  float64
#  13  txSts        11408 non-null  object
#  14  rxRsp        16008 non-null  float64
#  15  rxSts        16008 non-null  object
#  16  dw0          23000 non-null  object
#  17  dw1          7544 non-null   object
# ...

# %%
normal_df.isna().sum()
# Out:
# msgId              0
# timestamp          0
# error              0
# modeCode           0
# channel            0
# connType           0
# sa             11592
# ssa            11592
# da              6992
# dsa             6992
# wc              8832
# modeCodeVal    14168
# txRsp          11592
# txSts          11592
# rxRsp           6992
# rxSts           6992
# dw0                0
# dw1            15456
# dw2            16376
# dw3            16376
# dw4            16376
# dw5            16376
# dw6            16376
# dw7            16376
# dw8            16376
# dw9            20792
# dw10           20792
# dw11           20792
# dw12           20792
# dw13           20792
# dw14           20792
# dw15           20792
# dw16           20792
# dw17           20792
# dw18           20792
# dw19           20792
# dw20           21344
# dw21           21344
# dw22           21344
# dw23           21344
# dw24           21344
# dw25           21344
# dw26           21344
# ...

# %%
normal_df[normal_df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [msgId, timestamp, error, modeCode, channel, connType, sa, ssa, da, dsa, wc, modeCodeVal, txRsp, txSts, rxRsp, rxSts, dw0, dw1, dw2, dw3, dw4, dw5, dw6, dw7, dw8, dw9, dw10, dw11, dw12, dw13, dw14, dw15, dw16, dw17, dw18, dw19, dw20, dw21, dw22, dw23, dw24, dw25, dw26, dw27, dw28, dw29, dw30, dw31, malicious, injected, gap, msgTime]
# Index: []
#
# [0 rows x 52 columns]

# %% [markdown]
# Observations from 1553-Benign.csv: -
#
# 1. The dataset has 23,000 rows and 52 columns.
# 2. There are null values in the dataset.
# 3. The numerical fields are raw and not normalized.
# 4. There is no duplicate record.
# 5. The file contains only normal (benign) events

# %%
dos_df=pd.read_csv("..//Mil-STD-1553/Attack 1 (Basic DOS)/1553_dos_attack1.csv")

# %%
dos_df.head()
# Out:
#    msgId    timestamp  error  modeCode channel connType  sa  ssa   da   dsa  \
# 0      1  1134.816478  False      True       A   BC->RT NaN  NaN  1.0   0.0
# 1      2  1134.816557  False      True       A   BC->RT NaN  NaN  2.0   0.0
# 2      3  1134.816636  False      True       A   BC->RT NaN  NaN  3.0   0.0
# 3      4  1134.816715  False      True       A   BC->RT NaN  NaN  4.0   0.0
# 4      5  1134.816879  False     False       A   BC->RT NaN  NaN  1.0  20.0
#
#    ...  dw26  dw27  dw28 dw29  dw30 dw31 malicious injected   gap msgTime
# 0  ...   NaN   NaN   NaN  NaN   NaN  NaN     False    False   NaN    65.0
# 1  ...   NaN   NaN   NaN  NaN   NaN  NaN     False    False  14.0    65.0
# 2  ...   NaN   NaN   NaN  NaN   NaN  NaN     False    False  14.0    65.0
# 3  ...   NaN   NaN   NaN  NaN   NaN  NaN     False    False  14.0    65.0
# 4  ...   NaN   NaN   NaN  NaN   NaN  NaN     False    False  99.0    65.0
#
# [5 rows x 52 columns]

# %%
dos_df.tail()
# Out:
#      msgId    timestamp  error  modeCode channel connType   sa   ssa   da  \
# 143    144  1161.316478  False     False       A   RT->RT  0.0  20.0  3.0
# 144    145  1161.566478  False     False       A   RT->RT  0.0  20.0  3.0
# 145    146  1161.816478  False     False       A   RT->RT  0.0  20.0  3.0
# 146    147  1162.066478  False     False       A   RT->RT  0.0  20.0  3.0
# 147    148  1162.316478  False     False       A   RT->RT  0.0  20.0  3.0
#
#       dsa  ...  dw26  dw27  dw28 dw29  dw30 dw31 malicious injected       gap  \
# 143  20.0  ...   NaN   NaN   NaN  NaN   NaN  NaN      True    False  249887.0
# 144  20.0  ...   NaN   NaN   NaN  NaN   NaN  NaN      True    False  249888.0
# 145  20.0  ...   NaN   NaN   NaN  NaN   NaN  NaN      True    False  249887.0
# 146  20.0  ...   NaN   NaN   NaN  NaN   NaN  NaN      True    False  249888.0
# 147  20.0  ...   NaN   NaN   NaN  NaN   NaN  NaN      True    False  249887.0
#
#     msgTime
# 143   112.0
# 144   112.0
# ...

# %%
dos_df.shape
# Out:
# (148, 52)

# %%
dos_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148 entries, 0 to 147
# Data columns (total 52 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   msgId        148 non-null    int64
#  1   timestamp    148 non-null    float64
#  2   error        148 non-null    bool
#  3   modeCode     148 non-null    bool
#  4   channel      148 non-null    object
#  5   connType     148 non-null    object
#  6   sa           127 non-null    float64
#  7   ssa          127 non-null    float64
#  8   da           136 non-null    float64
#  9   dsa          136 non-null    float64
#  10  wc           132 non-null    float64
#  11  modeCodeVal  16 non-null     float64
#  12  txRsp        127 non-null    float64
#  13  txSts        127 non-null    object
#  14  rxRsp        136 non-null    float64
#  15  rxSts        136 non-null    object
#  16  dw0          148 non-null    object
#  17  dw1          13 non-null     object
# ...

# %%
dos_df.isna().sum()
# Out:
# msgId            0
# timestamp        0
# error            0
# modeCode         0
# channel          0
# connType         0
# sa              21
# ssa             21
# da              12
# dsa             12
# wc              16
# modeCodeVal    132
# txRsp           21
# txSts           21
# rxRsp           12
# rxSts           12
# dw0              0
# dw1            135
# dw2            136
# dw3            136
# dw4            136
# dw5            136
# dw6            136
# dw7            136
# dw8            136
# dw9            144
# dw10           144
# dw11           144
# dw12           144
# dw13           144
# dw14           144
# dw15           144
# dw16           144
# dw17           144
# dw18           144
# dw19           144
# dw20           145
# dw21           145
# dw22           145
# dw23           145
# dw24           145
# dw25           145
# dw26           145
# dw27           145
# dw28           145
# dw29           145
# dw30           145
# ...

# %%
dos_df[dos_df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [msgId, timestamp, error, modeCode, channel, connType, sa, ssa, da, dsa, wc, modeCodeVal, txRsp, txSts, rxRsp, rxSts, dw0, dw1, dw2, dw3, dw4, dw5, dw6, dw7, dw8, dw9, dw10, dw11, dw12, dw13, dw14, dw15, dw16, dw17, dw18, dw19, dw20, dw21, dw22, dw23, dw24, dw25, dw26, dw27, dw28, dw29, dw30, dw31, malicious, injected, gap, msgTime]
# Index: []
#
# [0 rows x 52 columns]

# %%
broadcast_df=pd.read_csv("..//Mil-STD-1553/Attack 2 (Broadcast DOS)/1553_dos_attack2(broadcast).csv")

# %%
broadcast_df.head()
# Out:
#    msgId    timestamp  error  modeCode channel connType  sa  ssa   da   dsa  \
# 0      1  1055.970487  False      True       A   BC->RT NaN  NaN  1.0   0.0
# 1      2  1055.970566  False      True       A   BC->RT NaN  NaN  2.0   0.0
# 2      3  1055.970645  False      True       A   BC->RT NaN  NaN  3.0   0.0
# 3      4  1055.970724  False      True       A   BC->RT NaN  NaN  4.0   0.0
# 4      5  1055.970888  False     False       A   BC->RT NaN  NaN  1.0  20.0
#
#    ...  dw26  dw27  dw28 dw29  dw30 dw31 malicious injected   gap msgTime
# 0  ...   NaN   NaN   NaN  NaN   NaN  NaN     False    False   NaN    65.0
# 1  ...   NaN   NaN   NaN  NaN   NaN  NaN     False    False  14.0    65.0
# 2  ...   NaN   NaN   NaN  NaN   NaN  NaN     False    False  14.0    65.0
# 3  ...   NaN   NaN   NaN  NaN   NaN  NaN     False    False  14.0    65.0
# 4  ...   NaN   NaN   NaN  NaN   NaN  NaN     False    False  99.0    65.0
#
# [5 rows x 52 columns]

# %%
broadcast_df.tail()
# Out:
#      msgId    timestamp  error  modeCode channel connType   sa   ssa    da  \
# 368    369  1097.720612  False     False       A   RT->RT  0.0   1.0  31.0
# 369    370  1097.970486  False     False       A   RT->RT  0.0  20.0   3.0
# 370    371  1097.970612  False     False       A   RT->RT  0.0   1.0  31.0
# 371    372  1098.220486  False     False       A   RT->RT  0.0  20.0   3.0
# 372    373  1098.220612  False     False       A   RT->RT  0.0   1.0  31.0
#
#       dsa  ...  dw26  dw27  dw28 dw29  dw30 dw31 malicious injected       gap  \
# 368   1.0  ...   NaN   NaN   NaN  NaN   NaN  NaN      True    False      14.0
# 369  20.0  ...   NaN   NaN   NaN  NaN   NaN  NaN      True    False  249789.0
# 370   1.0  ...   NaN   NaN   NaN  NaN   NaN  NaN      True    False      14.0
# 371  20.0  ...   NaN   NaN   NaN  NaN   NaN  NaN      True    False  249789.0
# 372   1.0  ...   NaN   NaN   NaN  NaN   NaN  NaN      True    False      14.0
#
#     msgTime
# 368    85.0
# 369   112.0
# ...

# %%
broadcast_df.shape
# Out:
# (373, 52)

# %%
broadcast_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 373 entries, 0 to 372
# Data columns (total 52 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   msgId        373 non-null    int64
#  1   timestamp    373 non-null    float64
#  2   error        373 non-null    bool
#  3   modeCode     373 non-null    bool
#  4   channel      373 non-null    object
#  5   connType     373 non-null    object
#  6   sa           352 non-null    float64
#  7   ssa          352 non-null    float64
#  8   da           361 non-null    float64
#  9   dsa          361 non-null    float64
#  10  wc           357 non-null    float64
#  11  modeCodeVal  16 non-null     float64
#  12  txRsp        352 non-null    float64
#  13  txSts        352 non-null    object
#  14  rxRsp        195 non-null    float64
#  15  rxSts        195 non-null    object
#  16  dw0          373 non-null    object
#  17  dw1          13 non-null     object
# ...

# %%
broadcast_df.isna().sum()
# Out:
# msgId            0
# timestamp        0
# error            0
# modeCode         0
# channel          0
# connType         0
# sa              21
# ssa             21
# da              12
# dsa             12
# wc              16
# modeCodeVal    357
# txRsp           21
# txSts           21
# rxRsp          178
# rxSts          178
# dw0              0
# dw1            360
# dw2            361
# dw3            361
# dw4            361
# dw5            361
# dw6            361
# dw7            361
# dw8            361
# dw9            369
# dw10           369
# dw11           369
# dw12           369
# dw13           369
# dw14           369
# dw15           369
# dw16           369
# dw17           369
# dw18           369
# dw19           369
# dw20           370
# dw21           370
# dw22           370
# dw23           370
# dw24           370
# dw25           370
# dw26           370
# dw27           370
# dw28           370
# dw29           370
# dw30           370
# ...
